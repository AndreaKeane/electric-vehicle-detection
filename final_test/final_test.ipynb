# %%
# Setup
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from pathlib import Path

# Import custom methods
import predict_setup as setup

# Ignore deprecation warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pickle_path = Path('/Users/andreakeane/Documents/DataScience/GridCure_Problems/pickles/')

# Retrieve final TEST data
test = pd.read_pickle(pickle_path / "test.pkl")
test.shape
# Out:
# (699, 2880)

# %%
# Part A Predictions
a_predicts = setup.predict_a(test)
print(a_predicts['predict'].value_counts())
# Out:
# (699, 1)
# False    518
# True     181
# Name: predict, dtype: int64

# %%
# Part B Predictions
b_predicts = setup.predict_b(test)
b_predicts.to_pickle('results.pkl')
b_predicts.to_csv('results.csv')
b_predicts
# Out:
# 99957 Rows were dropped for NA reasons.
#                     0                                                      \
#          Interval_144 Interval_145 Interval_146 Interval_147 Interval_148
# House ID
# 11643173     0.000000     0.153846     0.000000     0.000000     0.000000
# 11655020     0.076923     0.000000     0.000000     0.000000     0.000000
# 11644367     0.000000     0.000000     0.000000     0.000000     0.000000
# 11633356     0.000000     0.000000     0.000000     0.000000     0.000000
# 11649905     0.000000     0.000000     0.000000     0.000000     0.000000
# 11647887     0.000000     0.000000     0.000000     0.000000     0.000000
# 11647719     0.000000     0.000000     0.000000     0.000000     0.000000
# 11649920     0.000000     0.000000     0.000000     0.000000     0.076923
# 11634330     0.000000     0.000000     0.000000     0.000000     0.000000
# 11633656     0.000000     0.000000     0.000000     0.000000     0.000000
# ...
